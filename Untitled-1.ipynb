# %%
from einops import rearrange, reduce, repeat
import numpy as np

# %%
x = np.random.rand(8, 10, 16)

# %%
y = rearrange(x, "b (p t) d -> b p t d", p=2)

# %%
y.shape
# Out:
# (8, 2, 5, 16)

# %%
z = np.random.rand(2, 3)

# %%
w = repeat(z, "... -> x ...", x = 3)

# %%
w.shape
# Out:
# (3, 2, 3)

# %%
w
# Out:
# array([[[0.49657109, 0.52323389, 0.47404402],
#         [0.01994771, 0.56012146, 0.3251534 ]],
#
#        [[0.49657109, 0.52323389, 0.47404402],
#         [0.01994771, 0.56012146, 0.3251534 ]],
#
#        [[0.49657109, 0.52323389, 0.47404402],
#         [0.01994771, 0.56012146, 0.3251534 ]]])

# %%
q = np.random.rand(2, 4, 5, 1, 3)
k = np.random.rand(2, 4, 6, 1, 3)
q_ = rearrange(q, "b p t h d -> (b p) t h d")
k_ = rearrange(k, "b p T h d -> (b p) T h d")

# %%
q_.shape
# Out:
# (8, 5, 1, 3)

# %%
(q[0, 0].squeeze() @ k[0, 0].squeeze().T)
# Out:
# array([[0.75008027, 1.09026072, 0.41217021, 0.25257082, 1.01247137,
#         0.86615209],
#        [0.52323619, 0.97465198, 0.41852974, 0.43844271, 0.81660024,
#         0.61017446],
#        [0.82302213, 1.21990252, 0.41481094, 0.23510208, 1.15738577,
#         1.05603723],
#        [0.58979729, 1.10420923, 0.35060775, 0.33069759, 1.00565737,
#         0.94000435],
#        [0.71960346, 1.31198019, 0.69463044, 0.75470739, 1.01825805,
#         0.56231248]])

# %%
# %timeit a1 = np.einsum("bpthd, bpThd -> bphtT", q, k)
# Out:
# 9.46 µs ± 92.1 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
a1.shape
# Out:
# (2, 4, 1, 5, 6)

# %%
# %timeit a2 = np.einsum("bthd, bThd -> bhtT", q_, k_)
# Out:
# 9.61 µs ± 216 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
a3 = rearrange(a2, "(b p) h t T-> b p h t T", p=4)

# %%
a3.shape
# Out:
# (2, 4, 1, 5, 6)

# %%
a1 == a3
# Out:
# array([[[[[ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True]]],
#
#
#         [[[ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True]]],
#
#
#         [[[ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True]]],
#
#
#         [[[ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True]]]],
#
#
#
#        [[[[ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True]]],
#
#
#         [[[ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True]]],
#
#
#         [[[ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True]]],
#
#
#         [[[ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True],
#           [ True,  True,  True,  True,  True,  True]]]]])

# %%
import haiku as hk
import numpy as np
import jax.numpy as jnp
from typing import Optional
from haiku._src.typing import Initializer

# %%
class MultiChannelLinear(hk.Module):
    """
    N parallel affine transformations.
    """

    def __init__(
        self,
        num_channels: int,
        output_features: int,
        init_scale: float = 1.0,
        with_bias: bool = True,
        b_init: Optional[Initializer] = None,
        name: Optional[str] = None,
    ):
        super().__init__(name=name)
        self._num_channels = num_channels
        self._output_features = output_features
        self._init_scale = init_scale
        self._with_bias = with_bias
        self._b_init = b_init or jnp.zeros
        self._name = name

    def __call__(self, inputs):
        """
        Args:
            inputs: [batch, num_pathways, index_dim, num_channels]
        """
        num_channels = self._num_channels
        input_features = self._input_features = inputs.shape[-1]
        output_features = self._output_features
        dtype = inputs.dtype

        init_scale = self._init_scale
        if init_scale is None:
            stddev = 1.0 / np.sqrt(self._input_features)
            w_init = hk.initializers.TruncatedNormal(stddev=stddev)
        else:
            w_init = hk.initializers.VarianceScaling(init_scale)
        w = hk.get_parameter(
            "w", [num_channels, input_features, output_features], dtype, init=w_init
        )

        out = jnp.matmul(inputs, w)

        if self._with_bias:
            b = hk.get_parameter(
                "b", [num_channels, 1, output_features], dtype, init=self._b_init
            )
            b = jnp.broadcast_to(b, out.shape)
        out = out + b

        return out

# %%
def multi_channel_linear(x):
    module = MultiChannelLinear(num_channels=4, output_features=16)
    return module(x)

# %%
forward = hk.transform(multi_channel_linear)

# %%
import jax
key = jax.random.PRNGKey(0)
x = jax.random.normal(key, (2, 4, 5, 8))
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
params = forward.init(rng=key, x=dummy_x)
# Out:
# /home/awehrs/miniconda3/envs/pathways/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py:3698: UserWarning: Explicitly requested dtype float64 requested in zeros is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "zeros")

# %%
x = jnp.ones((2, 4, 5, 8))
y = forward.apply(params=params, x=x, rng=key)

# %%
y.shape
# Out:
# (2, 4, 5, 16)

# %%
y[0, 1]
# Out:
# DeviceArray([[-0.18306366, -1.1214032 , -0.20981392,  0.02430223,
#               -0.758953  ,  0.19539857,  0.14526668, -0.4697502 ,
#               -0.37162304, -0.420932  ,  0.14927003,  0.21616359,
#                0.12027161,  0.455296  , -0.6907001 , -0.53500366],
#              [-0.18306366, -1.1214032 , -0.20981392,  0.02430223,
#               -0.758953  ,  0.19539857,  0.14526668, -0.4697502 ,
#               -0.37162304, -0.420932  ,  0.14927003,  0.21616359,
#                0.12027161,  0.455296  , -0.6907001 , -0.53500366],
#              [-0.18306366, -1.1214032 , -0.20981392,  0.02430223,
#               -0.758953  ,  0.19539857,  0.14526668, -0.4697502 ,
#               -0.37162304, -0.420932  ,  0.14927003,  0.21616359,
#                0.12027161,  0.455296  , -0.6907001 , -0.53500366],
#              [-0.18306366, -1.1214032 , -0.20981392,  0.02430223,
#               -0.758953  ,  0.19539857,  0.14526668, -0.4697502 ,
#               -0.37162304, -0.420932  ,  0.14927003,  0.21616359,
#                0.12027161,  0.455296  , -0.6907001 , -0.53500366],
#              [-0.18306366, -1.1214032 , -0.20981392,  0.02430223,
#               -0.758953  ,  0.19539857,  0.14526668, -0.4697502 ,
#               -0.37162304, -0.420932  ,  0.14927003,  0.21616359,
#                0.12027161,  0.455296  , -0.6907001 , -0.53500366]],            dtype=float32)

# %%
def regular_linear(x):
    module = hk.Linear(16)
    return module(x)

# %%
forward2 = hk.transform(regular_linear)

# %%
params2 = forward2.init(rng=key, x=dummy_x)
# Out:
# /home/awehrs/miniconda3/envs/pathways/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py:3698: UserWarning: Explicitly requested dtype float64 requested in zeros is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "zeros")

# %%
y2 = forward2.apply(params=params2, x=x, rng=key)

# %%
y2.shape
# Out:
# (2, 4, 5, 16)

# %%
y2[0, 3]
# Out:
# DeviceArray([[ 0.23766805,  0.09935351,  0.6060016 ,  1.5810465 ,
#               -1.6784463 ,  2.7004874 ,  0.6521029 , -1.4530311 ,
#               -0.5496504 , -0.12809707, -0.01297408, -1.8025329 ,
#               -0.6704819 , -0.3872682 , -0.90747887, -0.15702218],
#              [ 0.23766805,  0.09935351,  0.6060016 ,  1.5810465 ,
#               -1.6784463 ,  2.7004874 ,  0.6521029 , -1.4530311 ,
#               -0.5496504 , -0.12809707, -0.01297408, -1.8025329 ,
#               -0.6704819 , -0.3872682 , -0.90747887, -0.15702218],
#              [ 0.23766805,  0.09935351,  0.6060016 ,  1.5810465 ,
#               -1.6784463 ,  2.7004874 ,  0.6521029 , -1.4530311 ,
#               -0.5496504 , -0.12809707, -0.01297408, -1.8025329 ,
#               -0.6704819 , -0.3872682 , -0.90747887, -0.15702218],
#              [ 0.23766805,  0.09935351,  0.6060016 ,  1.5810465 ,
#               -1.6784463 ,  2.7004874 ,  0.6521029 , -1.4530311 ,
#               -0.5496504 , -0.12809707, -0.01297408, -1.8025329 ,
#               -0.6704819 , -0.3872682 , -0.90747887, -0.15702218],
#              [ 0.23766805,  0.09935351,  0.6060016 ,  1.5810465 ,
#               -1.6784463 ,  2.7004874 ,  0.6521029 , -1.4530311 ,
#               -0.5496504 , -0.12809707, -0.01297408, -1.8025329 ,
#               -0.6704819 , -0.3872682 , -0.90747887, -0.15702218]],            dtype=float32)

# %%
# Out:
# array([[[[0.8303461 , 0.72315708, 0.82299629, ..., 0.56444649,
#           0.96323568, 0.73136931],
#          [0.03498549, 0.06814834, 0.56369268, ..., 0.96849281,
#           0.12923999, 0.58238242],
#          [0.81883653, 0.02746022, 0.17267796, ..., 0.37578728,
#           0.73969488, 0.66038231],
#          [0.60496612, 0.77983048, 0.26959339, ..., 0.76893138,
#           0.75972568, 0.65070706],
#          [0.72225114, 0.65261821, 0.82927554, ..., 0.62158078,
#           0.12911551, 0.6679843 ]],
#
#         [[0.96223099, 0.73722385, 0.41100629, ..., 0.21013132,
#           0.54172832, 0.44045069],
#          [0.19218966, 0.34728459, 0.50591513, ..., 0.69986711,
#           0.02934971, 0.912753  ],
#          [0.91654037, 0.82316081, 0.28468506, ..., 0.92637637,
#           0.36311632, 0.46934494],
#          [0.09603709, 0.67139424, 0.58297449, ..., 0.79178829,
#           0.07896961, 0.74882819],
#          [0.01713771, 0.04372111, 0.57681133, ..., 0.94427153,
#           0.56619509, 0.14182395]],
#
#         [[0.89540614, 0.83356946, 0.58402549, ..., 0.37869902,
#           0.2592095 , 0.22651988],
#          [0.95015948, 0.56775812, 0.96858243, ..., 0.11507441,
#           0.7712035 , 0.78033145],
#          [0.03631945, 0.91734037, 0.74504276, ..., 0.74478854,
#           0.2768855 , 0.81175344],
#          [0.79994713, 0.97270358, 0.6671108 , ..., 0.42828512,
#           0.69668289, 0.23105675],
#          [0.84196463, 0.40037186, 0.24504857, ..., 0.27279977,
#           0.01919029, 0.75387105]],
#
#         [[0.66500375, 0.45886338, 0.34652049, ..., 0.84122191,
#           0.21737903, 0.99749819],
#          [0.91841821, 0.96733613, 0.51532205, ..., 0.46935841,
#           0.37376098, 0.94948904],
#          [0.58427034, 0.1688701 , 0.84168012, ..., 0.70660785,
#           0.50661545, 0.20609504],
#          [0.9978882 , 0.84467974, 0.82292643, ..., 0.4234878 ,
#           0.32282315, 0.62291501],
#          [0.17193399, 0.38248471, 0.86161739, ..., 0.65785315,
#           0.19352792, 0.47393018]]],
#
#
#        [[[0.1014096 , 0.91683026, 0.00138055, ..., 0.36033303,
#           0.24929949, 0.44604877],
#          [0.86428798, 0.38692858, 0.01193135, ..., 0.8757743 ,
#           0.96166033, 0.62218864],
#          [0.34363787, 0.85420836, 0.16477311, ..., 0.46054977,
#           0.23895864, 0.71041393],
#          [0.14659122, 0.71164413, 0.30475377, ..., 0.96873857,
#           0.61088955, 0.76896935],
#          [0.27527322, 0.77017938, 0.90509542, ..., 0.05725564,
#           0.91769727, 0.50362599]],
#
#         [[0.05922984, 0.51389156, 0.76030548, ..., 0.18859676,
#           0.16049463, 0.50944737],
#          [0.9894397 , 0.85979051, 0.95625353, ..., 0.98216417,
#           0.10532219, 0.79180697],
#          [0.32740913, 0.48900914, 0.25571139, ..., 0.90869293,
#           0.80083797, 0.66117483],
#          [0.11043573, 0.0884595 , 0.23532948, ..., 0.84149953,
#           0.45936509, 0.03738112],
#          [0.87660146, 0.68381788, 0.24082619, ..., 0.48608157,
#           0.47434152, 0.73017495]],
#
#         [[0.92860729, 0.24077245, 0.41072651, ..., 0.52758322,
#           0.89283865, 0.83034249],
#          [0.89090493, 0.22687785, 0.60746628, ..., 0.38978033,
#           0.71394729, 0.20984006],
#          [0.31491406, 0.39184551, 0.21021497, ..., 0.49858739,
#           0.40472976, 0.32375487],
#          [0.54273106, 0.15512401, 0.44112666, ..., 0.81131984,
#           0.47861789, 0.47080967],
#          [0.3206684 , 0.15582808, 0.97605186, ..., 0.20181579,
#           0.19538632, 0.01641981]],
#
#         [[0.49130574, 0.45860917, 0.32948589, ..., 0.26058207,
#           0.0115281 , 0.60190063],
#          [0.78716581, 0.40268099, 0.80651023, ..., 0.49340317,
#           0.14164504, 0.28170684],
#          [0.39755396, 0.12181534, 0.93805884, ..., 0.0756397 ,
#           0.40100031, 0.68025182],
#          [0.60183896, 0.54176434, 0.16523673, ..., 0.43315232,
#           0.66518061, 0.35884722],
#          [0.45589778, 0.02399146, 0.20583919, ..., 0.45098564,
#           0.93096495, 0.6496675 ]]],
#
#
#        [[[0.55064715, 0.78965501, 0.19149742, ..., 0.77957688,
#           0.71640722, 0.1990207 ],
#          [0.01489499, 0.33736247, 0.3922675 , ..., 0.71115172,
#           0.24496995, 0.54178175],
#          [0.66382751, 0.76404215, 0.79841742, ..., 0.81787327,
#           0.35105194, 0.76302777],
#          [0.00209106, 0.65111366, 0.75409908, ..., 0.68303252,
#           0.6808633 , 0.69397215],
#          [0.91080346, 0.50461843, 0.46153877, ..., 0.23493262,
#           0.71109642, 0.33545869]],
#
#         [[0.51535699, 0.300838  , 0.91648736, ..., 0.23479267,
#           0.40299836, 0.85172399],
#          [0.41170079, 0.66144616, 0.16897505, ..., 0.33480942,
#           0.46024409, 0.77094015],
#          [0.59459835, 0.2245702 , 0.67465325, ..., 0.65818573,
#           0.58306404, 0.4732089 ],
#          [0.10486491, 0.54778925, 0.40067912, ..., 0.42807815,
#           0.07320427, 0.16758654],
#          [0.70367276, 0.19481004, 0.07465448, ..., 0.39060994,
#           0.36468953, 0.61845102]],
#
#         [[0.01896617, 0.44025447, 0.26237859, ..., 0.3240016 ,
#           0.73824595, 0.39152889],
#          [0.96603636, 0.88156139, 0.57025516, ..., 0.91145995,
#           0.52473761, 0.47115655],
#          [0.96119028, 0.41822782, 0.47827408, ..., 0.47273128,
#           0.65041412, 0.58722882],
#          [0.77283676, 0.38362086, 0.87407554, ..., 0.96617087,
#           0.72811276, 0.22869504],
#          [0.10178947, 0.28603217, 0.95767023, ..., 0.13111982,
#           0.81521692, 0.66462669]],
#
#         [[0.1023025 , 0.76572915, 0.08217283, ..., 0.89433159,
#           0.94856126, 0.17585887],
#          [0.80614111, 0.37700631, 0.97189995, ..., 0.82757996,
#           0.93703804, 0.25338914],
#          [0.22995543, 0.09129129, 0.7635142 , ..., 0.26405868,
#           0.32560877, 0.43121042],
#          [0.42674792, 0.88291871, 0.19895773, ..., 0.30969292,
#           0.37432855, 0.63853845],
#          [0.80736204, 0.01344579, 0.22012911, ..., 0.61561738,
#           0.57564858, 0.11839358]]],
#
#
#        ...,
#
#
#        [[[0.63647639, 0.59097194, 0.95239796, ..., 0.06339346,
#           0.33349118, 0.64558173],
#          [0.68476099, 0.83601697, 0.31469997, ..., 0.06082866,
#           0.96663185, 0.2454423 ],
#          [0.81210885, 0.96629015, 0.99644277, ..., 0.4732868 ,
#           0.35907316, 0.001767  ],
#          [0.84110177, 0.78088376, 0.72562629, ..., 0.72783765,
#           0.97008881, 0.81840493],
#          [0.47138056, 0.0327458 , 0.5852541 , ..., 0.79501208,
#           0.55537054, 0.29707498]],
#
#         [[0.92734308, 0.3969193 , 0.17952263, ..., 0.64285315,
#           0.16668391, 0.45694892],
#          [0.78325054, 0.10225535, 0.38770564, ..., 0.06880576,
#           0.34533685, 0.6362948 ],
#          [0.55028998, 0.06834897, 0.92953096, ..., 0.25375169,
#           0.81045117, 0.97847109],
#          [0.36784731, 0.62018762, 0.28197304, ..., 0.75941079,
#           0.92779343, 0.30946064],
#          [0.54385401, 0.83894629, 0.04627858, ..., 0.95733823,
#           0.47308731, 0.34780975]],
#
#         [[0.32764688, 0.73367522, 0.95333516, ..., 0.93266047,
#           0.40333554, 0.51615837],
#          [0.05600735, 0.39621925, 0.14269909, ..., 0.07851231,
#           0.38364976, 0.86193628],
#          [0.83836166, 0.66019585, 0.11207805, ..., 0.36055972,
#           0.09554134, 0.56707061],
#          [0.49940259, 0.20046355, 0.26648206, ..., 0.02416703,
#           0.85941616, 0.34418802],
#          [0.94971299, 0.2238757 , 0.06245256, ..., 0.47251243,
#           0.2807223 , 0.9466986 ]],
#
#         [[0.39662523, 0.00614341, 0.3850436 , ..., 0.6926933 ,
#           0.96972719, 0.22933387],
#          [0.2343319 , 0.77279607, 0.0496554 , ..., 0.58799013,
#           0.09139467, 0.62013923],
#          [0.03499171, 0.70770328, 0.71793648, ..., 0.5572075 ,
#           0.32542357, 0.39530384],
#          [0.29473522, 0.18070418, 0.18112224, ..., 0.42990223,
#           0.84558441, 0.51442299],
#          [0.22422255, 0.98081584, 0.75088665, ..., 0.34231495,
#           0.23405016, 0.84548971]]],
#
#
#        [[[0.5947072 , 0.71269844, 0.43988458, ..., 0.5334142 ,
#           0.70200303, 0.55435311],
#          [0.16153881, 0.0688279 , 0.68948121, ..., 0.23362832,
#           0.71629518, 0.79623919],
#          [0.33551881, 0.10984839, 0.18190287, ..., 0.38769515,
#           0.6627746 , 0.45473768],
#          [0.24539898, 0.8890985 , 0.79617048, ..., 0.40941991,
#           0.21700342, 0.44544265],
#          [0.3956101 , 0.9654444 , 0.9040943 , ..., 0.41306008,
#           0.65711416, 0.3289146 ]],
#
#         [[0.06410604, 0.83003661, 0.92980802, ..., 0.06036437,
#           0.03990235, 0.53693789],
#          [0.27724367, 0.39509052, 0.38064611, ..., 0.84437242,
#           0.23087986, 0.07060276],
#          [0.73271979, 0.46356152, 0.78925764, ..., 0.23049741,
#           0.63642104, 0.33741501],
#          [0.38326621, 0.05767881, 0.69725234, ..., 0.35823892,
#           0.31225772, 0.30987266],
#          [0.72930886, 0.2872387 , 0.65607776, ..., 0.01493441,
#           0.22411275, 0.89594467]],
#
#         [[0.61144233, 0.39161406, 0.31630164, ..., 0.69286599,
#           0.48307663, 0.06361514],
#          [0.7294021 , 0.71220491, 0.67339738, ..., 0.8244221 ,
#           0.59855267, 0.54258019],
#          [0.1988291 , 0.0213993 , 0.17730468, ..., 0.42628597,
#           0.88814752, 0.31185379],
#          [0.67063248, 0.80773545, 0.55687095, ..., 0.34778334,
#           0.31197529, 0.11129346],
#          [0.5729465 , 0.84605377, 0.8084756 , ..., 0.18624981,
#           0.63348845, 0.75517096]],
#
#         [[0.43180715, 0.45165738, 0.63802216, ..., 0.07329193,
#           0.82056801, 0.13968579],
#          [0.5940759 , 0.83002138, 0.4297879 , ..., 0.76789438,
#           0.11280142, 0.3765385 ],
#          [0.92658832, 0.9576074 , 0.69197714, ..., 0.06088257,
#           0.81521591, 0.05507812],
#          [0.3911282 , 0.45967186, 0.06430209, ..., 0.69751511,
#           0.27662665, 0.08022875],
#          [0.23707285, 0.93575156, 0.87083765, ..., 0.14590715,
#           0.34874017, 0.4187258 ]]],
#
#
#        [[[0.51071477, 0.90935641, 0.43083272, ..., 0.46470896,
#           0.24765573, 0.35681331],
#          [0.2107467 , 0.23322787, 0.92082166, ..., 0.98660985,
#           0.04079418, 0.08417839],
#          [0.31599175, 0.06079954, 0.2137207 , ..., 0.5188806 ,
#           0.77867435, 0.70629431],
#          [0.79933389, 0.46952406, 0.20745927, ..., 0.23847107,
#           0.17980867, 0.41450386],
#          [0.09711364, 0.61811761, 0.45203608, ..., 0.07384472,
#           0.55404808, 0.0038685 ]],
#
#         [[0.75455126, 0.56236323, 0.26584474, ..., 0.88703064,
#           0.27771562, 0.65391548],
#          [0.04680568, 0.06374384, 0.37101622, ..., 0.94340626,
#           0.12326114, 0.963052  ],
#          [0.59780267, 0.66894404, 0.60201895, ..., 0.82536704,
#           0.13974305, 0.85676271],
#          [0.29924721, 0.90205576, 0.68985904, ..., 0.79572751,
#           0.56160694, 0.19464202],
#          [0.37805682, 0.2086606 , 0.25399301, ..., 0.42409384,
#           0.19352201, 0.77094537]],
#
#         [[0.36123029, 0.74087726, 0.48831079, ..., 0.34609263,
#           0.03294739, 0.75390263],
#          [0.72449629, 0.87823819, 0.79685401, ..., 0.87679729,
#           0.37958424, 0.86559476],
#          [0.83254216, 0.66066418, 0.51087829, ..., 0.83365076,
#           0.65699978, 0.96449745],
#          [0.37131462, 0.9720452 , 0.5040547 , ..., 0.47844157,
#           0.0367861 , 0.78778477],
#          [0.13897661, 0.25876317, 0.03495308, ..., 0.31368315,
#           0.86087844, 0.82490316]],
#
#         [[0.57778848, 0.26843352, 0.54464994, ..., 0.33454514,
#           0.07153344, 0.81470586],
#          [0.48106036, 0.88368666, 0.91004131, ..., 0.08947286,
#           0.62574444, 0.04990668],
#          [0.23498584, 0.33325649, 0.41951139, ..., 0.2195186 ,
#           0.02379924, 0.91322835],
#          [0.85238679, 0.85433816, 0.05726817, ..., 0.84512677,
#           0.45269981, 0.01791394],
#          [0.11040711, 0.6437072 , 0.64669893, ..., 0.93500878,
#           0.78933577, 0.95447765]]]])
